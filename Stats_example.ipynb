# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import mannwhitneyu
from scipy.stats import friedmanchisquare
from scipy.stats import rankdata
import pandas as pd
import seaborn as sns

# %% [markdown]
# Loads Data: Iterates through a predefined list of representations (fixed-point, gray, ieee754, real-value) and attempts to load gnbg_results_<representation>.pkl files. It handles FileNotFoundError and general exceptions during loading.
#
# Combines and Filters Results: Merges all successfully loaded results into a single list (all_combined_results). It then filters these results to include only valid runs that contain instance, representation, and a finite final_error.
#
# Organizes Data for Analysis: Groups the valid final_error values by (instance, representation) pairs.
#
# Performs Statistical Comparison: Conducts Mann-Whitney U tests (a non-parametric statistical test) to compare the final_error distributions between different representations for each benchmark instance. It checks for sufficient data points and handles cases with constant data.
#
# Prints Statistical Summary: Outputs the p-values from the Mann-Whitney U tests, indicating statistical significance (at alpha=0.05), and provides an interpretation based on the medians of the compared representations.

# %%
print("Spojuji výsledky z jednotlivých běhů...")

representations_to_run = ['fixed-point', 'gray', 'ieee754', 'real-value']
all_combined_results = []
loaded_files_count = 0

for rep in representations_to_run:
    filename = f"gnbg_results_{rep}.pkl"
    try:
        with open(filename, 'rb') as f:
            results_for_rep = pickle.load(f)
            all_combined_results.extend(results_for_rep)
            print(f"Načteno {len(results_for_rep)} výsledků z {filename}")
            loaded_files_count += 1
    except FileNotFoundError:
        print(f"VAROVÁNÍ: Soubor {filename} nebyl nalezen. Přeskakuji.")
    except Exception as e:
        print(f"CHYBA při načítání souboru {filename}: {e}")

if not all_combined_results:
    print("CHYBA: Nepodařilo se načíst žádné výsledky. Analýza nemůže pokračovat.")
else:
    print(f"\nCelkem spojeno {len(all_combined_results)} výsledků z {loaded_files_count} souborů.")

results_by_instance_rep = {}
instances_with_results = set()
valid_results_count = 0

if all_combined_results:
    print("\nZpracovávám spojené výsledky pro analýzu...")
    for res in all_combined_results:
        if 'error' not in res and np.isfinite(res.get('final_error', float('inf'))):
            instance = res['instance']
            representation = res['representation']
            key = (instance, representation)
            if key not in results_by_instance_rep:
                results_by_instance_rep[key] = []
            results_by_instance_rep[key].append(res['final_error'])
            instances_with_results.add(instance)
            valid_results_count += 1
    instances_with_results = sorted(list(instances_with_results))
    print(f"Počet validních výsledků pro analýzu: {valid_results_count} z {len(all_combined_results)} celkem.")
    print(f"Nalezeny výsledky pro instance: {instances_with_results}")


if all_combined_results and results_by_instance_rep:
    print("\nProvádím statistické porovnání (Mann-Whitney U)...")
    statistical_comparison = {}
    alpha = 0.05

    for instance_name in instances_with_results:
        statistical_comparison[instance_name] = {}
        instance_reps = sorted(list(set(key[1] for key in results_by_instance_rep.keys() if key[0] == instance_name)))

        for i in range(len(instance_reps)):
            for j in range(i + 1, len(instance_reps)):
                rep1 = instance_reps[i]
                rep2 = instance_reps[j]
                key1 = (instance_name, rep1)
                key2 = (instance_name, rep2)
                data1 = results_by_instance_rep.get(key1, [])
                data2 = results_by_instance_rep.get(key2, [])
                min_samples_for_test = 5

                if len(data1) < min_samples_for_test or len(data2) < min_samples_for_test:
                    print(f"  INFO: Přeskakuji porovnání {rep1} vs {rep2} pro {instance_name} (málo dat: {len(data1)} vs {len(data2)})")
                    continue

                if len(set(data1)) <= 1 and len(set(data2)) <= 1:
                     u_stat, p_value = np.nan, 1.0 if np.isclose(np.mean(data1), np.mean(data2)) else 0.0
                else:
                    try:
                        u_stat, p_value = mannwhitneyu(data1, data2, alternative='two-sided', nan_policy='omit')
                    except ValueError as e:
                        print(f"  WARN: Chyba Mann-Whitney U pro {instance_name} ({rep1} vs {rep2}): {e}")
                        u_stat, p_value = np.nan, np.nan

                comparison_key = f"{rep1}_vs_{rep2}"
                statistical_comparison[instance_name][comparison_key] = {
                    'u_statistic': u_stat, 'p_value': p_value, 'n1': len(data1), 'n2': len(data2)
                }

    print("\nVýsledky statistického porovnání (p-hodnoty):")
    for instance_name in instances_with_results:
        print(f"\nInstance: {instance_name}")
        comparisons = statistical_comparison.get(instance_name, {})
        if not comparisons:
             print("  Pro tuto instanci nebylo provedeno žádné platné statistické porovnání (zkontrolujte počet běhů a validitu výsledků).")
             continue
        sorted_comparisons = sorted(comparisons.items())
        for comparison, stats in sorted_comparisons:
            p_value = stats['p_value']
            n1, n2 = stats['n1'], stats['n2']
            if np.isnan(p_value): significance_msg = "Test neprůkazný (NaN)"
            else: significant = "Ano" if p_value < alpha else "Ne"; significance_msg = f"p={p_value:.3f} (Významný: {significant})"
            print(f"  {comparison} (n={n1} vs {n2}): {significance_msg}")
            if not np.isnan(p_value) and p_value < alpha:
                 rep1, rep2 = comparison.split('_vs_')
                 data1 = results_by_instance_rep.get((instance_name, rep1), []); data2 = results_by_instance_rep.get((instance_name, rep2), [])
                 median1 = np.median(data1) if data1 else np.nan; median2 = np.median(data2) if data2 else np.nan
                 if not np.isnan(median1) and not np.isnan(median2):
                      if np.isclose(median1, median2): interpretation = "Mediány blízké."
                      elif median1 < median2: interpretation = f"'{rep1}' lepší (nižší medián)."
                      else: interpretation = f"'{rep2}' lepší (nižší medián)."
                      print(f"      Mediány: {median1:.3e} vs {median2:.3e} -> {interpretation}")
# Out:
# Spojuji výsledky z jednotlivých běhů...
# Načteno 744 výsledků z gnbg_results_fixed-point.pkl
# Načteno 744 výsledků z gnbg_results_gray.pkl
# Načteno 744 výsledků z gnbg_results_ieee754.pkl
# Načteno 744 výsledků z gnbg_results_real-value.pkl
#
# Celkem spojeno 2976 výsledků z 4 souborů.
#
# Zpracovávám spojené výsledky pro analýzu...
# Počet validních výsledků pro analýzu: 2976 z 2976 celkem.
# Nalezeny výsledky pro instance: ['f1', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f2', 'f20', 'f21', 'f22', 'f23', 'f24', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9']
#
# Provádím statistické porovnání (Mann-Whitney U)...
#
# Výsledky statistického porovnání (p-hodnoty):
#
# Instance: f1
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.041e+03 vs 5.672e+01 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.001 (Významný: Ano)
#       Mediány: 2.041e+03 vs 3.312e+03 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.041e+03 vs 2.766e-04 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.672e+01 vs 3.312e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.672e+01 vs 2.766e-04 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 3.312e+03 vs 2.766e-04 -> 'real-value' lepší (nižší medián).
#
# Instance: f10
#   fixed-point_vs_gray (n=31 vs 31): p=0.318 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.454e+03 vs 2.872e+03 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.454e+03 vs 4.850e-03 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.184e+03 vs 2.872e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.184e+03 vs 4.850e-03 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.872e+03 vs 4.850e-03 -> 'real-value' lepší (nižší medián).
#
# Instance: f11
#   fixed-point_vs_gray (n=31 vs 31): p=0.439 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.866 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.494e+04 vs 2.235e+04 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.375 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.378e+04 vs 2.235e+04 -> 'gray' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.430e+04 vs 2.235e+04 -> 'ieee754' lepší (nižší medián).
#
# Instance: f12
#   fixed-point_vs_gray (n=31 vs 31): p=0.989 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.778 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.081 (Významný: Ne)
#   gray_vs_ieee754 (n=31 vs 31): p=0.877 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.052 (Významný: Ne)
#   ieee754_vs_real-value (n=31 vs 31): p=0.054 (Významný: Ne)
#
# Instance: f13
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 3.569e+03 vs 2.049e+03 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.746 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 3.569e+03 vs 9.900e+02 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.049e+03 vs 3.832e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.049e+03 vs 9.900e+02 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 3.832e+03 vs 9.900e+02 -> 'real-value' lepší (nižší medián).
#
# Instance: f14
#   fixed-point_vs_gray (n=31 vs 31): p=0.481 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.266 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.231 (Významný: Ne)
#   gray_vs_ieee754 (n=31 vs 31): p=0.094 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.910 (Významný: Ne)
#   ieee754_vs_real-value (n=31 vs 31): p=0.022 (Významný: Ano)
#       Mediány: 1.496e+04 vs 1.293e+04 -> 'real-value' lepší (nižší medián).
#
# Instance: f15
#   fixed-point_vs_gray (n=31 vs 31): p=0.151 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.069 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.396e+00 vs 5.863e+00 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.003 (Významný: Ano)
#       Mediány: 6.279e+00 vs 6.542e+00 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.279e+00 vs 5.863e+00 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.542e+00 vs 5.863e+00 -> 'real-value' lepší (nižší medián).
#
# Instance: f16
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.957e+03 vs 6.016e+02 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.105 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.957e+03 vs 6.821e+02 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.016e+02 vs 4.042e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.368 (Významný: Ne)
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 4.042e+03 vs 6.821e+02 -> 'real-value' lepší (nižší medián).
#
# Instance: f17
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.353e+05 vs 5.640e+03 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.447 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.353e+05 vs 6.821e+02 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.640e+03 vs 1.652e+05 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.640e+03 vs 6.821e+02 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.652e+05 vs 6.821e+02 -> 'real-value' lepší (nižší medián).
#
# Instance: f18
#   fixed-point_vs_gray (n=31 vs 31): p=0.019 (Významný: Ano)
#       Mediány: 1.645e+04 vs 1.872e+04 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.422 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.004 (Významný: Ano)
#       Mediány: 1.645e+04 vs 1.973e+04 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.081 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.767 (Významný: Ne)
#   ieee754_vs_real-value (n=31 vs 31): p=0.012 (Významný: Ano)
#       Mediány: 1.569e+04 vs 1.973e+04 -> 'ieee754' lepší (nižší medián).
#
# Instance: f19
#   fixed-point_vs_gray (n=31 vs 31): p=0.052 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.105 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.210 (Významný: Ne)
#   gray_vs_ieee754 (n=31 vs 31): p=0.933 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.318 (Významný: Ne)
#   ieee754_vs_real-value (n=31 vs 31): p=0.414 (Významný: Ne)
#
# Instance: f2
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.473e+00 vs 1.166e+00 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.121 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.473e+00 vs 6.625e-01 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.166e+00 vs 1.492e+00 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.166e+00 vs 6.625e-01 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.492e+00 vs 6.625e-01 -> 'real-value' lepší (nižší medián).
#
# Instance: f20
#   fixed-point_vs_gray (n=31 vs 31): p=0.168 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.944 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.093e+01 vs 1.202e+01 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.159 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.039e+01 vs 1.202e+01 -> 'gray' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.090e+01 vs 1.202e+01 -> 'ieee754' lepší (nižší medián).
#
# Instance: f21
#   fixed-point_vs_gray (n=31 vs 31): p=0.023 (Významný: Ano)
#       Mediány: 5.304e+01 vs 7.977e+01 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.147 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.304e+01 vs 1.897e+01 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.014 (Významný: Ano)
#       Mediány: 7.977e+01 vs 3.549e+01 -> 'ieee754' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 7.977e+01 vs 1.897e+01 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.045 (Významný: Ano)
#       Mediány: 3.549e+01 vs 1.897e+01 -> 'real-value' lepší (nižší medián).
#
# Instance: f22
#   fixed-point_vs_gray (n=31 vs 31): p=0.398 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.508 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.340e+04 vs 9.085e+04 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.921 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 5.735e+04 vs 9.085e+04 -> 'gray' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.045e+04 vs 9.085e+04 -> 'ieee754' lepší (nižší medián).
#
# Instance: f23
#   fixed-point_vs_gray (n=31 vs 31): p=0.545 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.683 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.005 (Významný: Ano)
#       Mediány: 3.754e+01 vs 4.086e+01 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.248 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.001 (Významný: Ano)
#       Mediány: 3.688e+01 vs 4.086e+01 -> 'gray' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.035 (Významný: Ano)
#       Mediány: 3.778e+01 vs 4.086e+01 -> 'ieee754' lepší (nižší medián).
#
# Instance: f24
#   fixed-point_vs_gray (n=31 vs 31): p=0.159 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.414 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.515e+02 vs 1.717e+02 -> 'fixed-point' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.526 (Významný: Ne)
#   gray_vs_real-value (n=31 vs 31): p=0.014 (Významný: Ano)
#       Mediány: 1.599e+02 vs 1.717e+02 -> 'gray' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.001 (Významný: Ano)
#       Mediány: 1.568e+02 vs 1.717e+02 -> 'ieee754' lepší (nižší medián).
#
# Instance: f3
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.213e+08 vs 1.429e+07 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.213e+08 vs 1.664e+09 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.213e+08 vs 5.108e+01 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.429e+07 vs 1.664e+09 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.429e+07 vs 5.108e+01 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.664e+09 vs 5.108e+01 -> 'real-value' lepší (nižší medián).
#
# Instance: f4
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.249e+04 vs 8.934e+02 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.456 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.249e+04 vs 4.791e-03 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.934e+02 vs 1.291e+04 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.934e+02 vs 4.791e-03 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.291e+04 vs 4.791e-03 -> 'real-value' lepší (nižší medián).
#
# Instance: f5
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.845e+00 vs 2.484e+00 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.439 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.845e+00 vs 1.390e+00 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.484e+00 vs 2.847e+00 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.484e+00 vs 1.390e+00 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.847e+00 vs 1.390e+00 -> 'real-value' lepší (nižší medián).
#
# Instance: f6
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.839e+00 vs 2.573e+00 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.177 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.839e+00 vs 1.736e+00 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.573e+00 vs 2.856e+00 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.573e+00 vs 1.736e+00 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.856e+00 vs 1.736e+00 -> 'real-value' lepší (nižší medián).
#
# Instance: f7
#   fixed-point_vs_gray (n=31 vs 31): p=0.536 (Významný: Ne)
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.394e+03 vs 3.049e+03 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.394e+03 vs 1.506e-03 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.011 (Významný: Ano)
#       Mediány: 1.862e+03 vs 3.049e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.862e+03 vs 1.506e-03 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 3.049e+03 vs 1.506e-03 -> 'real-value' lepší (nižší medián).
#
# Instance: f8
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.734e+03 vs 1.024e+03 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.001 (Významný: Ano)
#       Mediány: 1.734e+03 vs 2.679e+03 -> 'fixed-point' lepší (nižší medián).
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.734e+03 vs 2.091e-03 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.024e+03 vs 2.679e+03 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 1.024e+03 vs 2.091e-03 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 2.679e+03 vs 2.091e-03 -> 'real-value' lepší (nižší medián).
#
# Instance: f9
#   fixed-point_vs_gray (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.937e+02 vs 4.772e+02 -> 'gray' lepší (nižší medián).
#   fixed-point_vs_ieee754 (n=31 vs 31): p=0.057 (Významný: Ne)
#   fixed-point_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 6.937e+02 vs 9.459e+01 -> 'real-value' lepší (nižší medián).
#   gray_vs_ieee754 (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 4.772e+02 vs 8.665e+02 -> 'gray' lepší (nižší medián).
#   gray_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 4.772e+02 vs 9.459e+01 -> 'real-value' lepší (nižší medián).
#   ieee754_vs_real-value (n=31 vs 31): p=0.000 (Významný: Ano)
#       Mediány: 8.665e+02 vs 9.459e+01 -> 'real-value' lepší (nižší medián).

# %% [markdown]
# Data Consolidation: Loads and combines results, similar to the previous cell, but focuses on best_fitness_found.
#
# Friedman Rank Test: For each unique benchmark instance, it conducts a Friedman test. This non-parametric test determines if there's a statistically significant difference among the multiple genetic algorithm representations based on their ranks (performance) across the experimental runs.
#
# Data Preprocessing: Before the Friedman test, it checks if enough data is available for each representation and, if necessary, truncates the number of runs to ensure all compared representations have an equal number of samples, which is a requirement for the Friedman test.
#
# Post-Hoc Nemenyi Test: If the Friedman test indicates a statistically significant difference, it then performs a Nemenyi post-hoc test. This test is used for pairwise comparisons between the representations to identify which specific pairs of representations show a significant difference. It calculates a Critical Difference (CD) value, and if the absolute difference in average ranks between two representations exceeds this CD, their performance is considered statistically different.
#
# Output: Prints detailed results of both the Friedman and Nemenyi tests, including chi-squared statistics, p-values, degrees of freedom, critical difference values, average ranks, and clear statements about statistical significance and performance interpretation.

# %%
print("Spojuji výsledky z jednotlivých běhů...")

representations_to_run = ['fixed-point', 'gray', 'ieee754', 'real-value']

all_combined_results = []
loaded_files_count = 0

for rep in representations_to_run:
    filename = f"gnbg_results_{rep}.pkl"
    try:
        with open(filename, 'rb') as f:
            results_for_rep = pickle.load(f)
            all_combined_results.extend(results_for_rep)
            print(f"Načteno {len(results_for_rep)} výsledků z {filename}")
            loaded_files_count += 1
    except FileNotFoundError:
        print(f"VAROVÁNÍ: Soubor {filename} nebyl nalezen. Přeskakuji.")
    except Exception as e:
        print(f"CHYBA při načítání souboru {filename}: {e}")

if not all_combined_results:
    print("CHYBA: Nepodařilo se načíst žádné výsledky. Analýza nemůže pokračovat.")
else:
    print(f"\nCelkem spojeno {len(all_combined_results)} výsledků z {loaded_files_count} souborů.")

    results_by_instance_rep = {}
    instances_with_results = set()

    for run in all_combined_results:
        if 'instance' in run and 'representation' in run and 'best_fitness_found' in run:
            instance_name = run['instance']
            representation_name = run['representation']
            best_fitness = run['best_fitness_found']

            key = (instance_name, representation_name)
            if key not in results_by_instance_rep:
                results_by_instance_rep[key] = []
            results_by_instance_rep[key].append(best_fitness)
            instances_with_results.add(instance_name)
        else:
            pass

    instances_with_results = sorted(list(instances_with_results))
    all_representations_found = sorted(list(set(key[1] for key in results_by_instance_rep.keys())))
    
    print(f"\nData připravena pro Friedmanův test.")
    print(f"Nalezené unikátní instance (problémové funkce): {instances_with_results}")
    print(f"Nalezené unikátní reprezentace (metody): {all_representations_found}")


    print("\n--- Friedman Rank Test (porovnání reprezentací pro každou instanci) ---")
    alpha = 0.05

    # Pro k = 2, 3, 4, 5, 6, 7, 8, 9, 10
    # Values from: https://www.stat.auckland.ac.nz/~wild/ChanceEnc/Ch10.friedman-test.pdf (or similar)
    # Critical values q_alpha for alpha=0.05 (two-tailed) and various k values (number of groups)
    # k:    2       3       4       5       6       7       8       9       10
    q_critical_values_nemenyi = {
        2: 1.960, 3: 2.343, 4: 2.569, 5: 2.728, 6: 2.850, 7: 2.950, 8: 3.030, 9: 3.099, 10: 3.161
    }


    if len(all_representations_found) < 2:
        print(f"INFO: Pro Friedmanův test je potřeba alespoň 2 reprezentace k porovnání. Nalezeno: {len(all_representations_found)}.")
    elif len(instances_with_results) < 1:
        print("INFO: Pro Friedmanův test je potřeba alespoň 1 instance. Žádné instance nalezeny.")
    else:
        for instance_name in instances_with_results:
            print(f"\n----- Instance: {instance_name} -----")
            
            data_for_friedman_instance = []
            reps_included_in_test = []

            for rep_name in all_representations_found:
                key = (instance_name, rep_name)
                data_points = results_by_instance_rep.get(key, [])
                
                if data_points:
                    data_for_friedman_instance.append(data_points)
                    reps_included_in_test.append(rep_name)
                else:
                    print(f"  INFO: Reprezentace '{rep_name}' nemá data pro instanci '{instance_name}' a bude přeskočena v tomto testu.")

            if len(data_for_friedman_instance) < 2:
                print(f"  INFO: Pro instanci '{instance_name}' není dostatek reprezentací s platnými daty k porovnání ({len(reps_included_in_test)} nalezeno). Test přeskočen.")
                continue

            num_runs_per_rep = [len(d) for d in data_for_friedman_instance]
            if len(set(num_runs_per_rep)) > 1:
                print(f"  VAROVÁNÍ: Pro instanci '{instance_name}' se počty běhů pro porovnávané reprezentace liší ({num_runs_per_rep}).")
                min_runs = min(num_runs_per_rep)
                data_for_friedman_instance = [d[:min_runs] for d in data_for_friedman_instance]
                print(f"  Data byla oříznuta na {min_runs} běhů pro každou reprezentaci pro instanci '{instance_name}'.")
            else:
                min_runs = num_runs_per_rep[0]

            if min_runs < 2:
                print(f"  INFO: Pro instanci '{instance_name}' je po oříznutí méně než 2 běhy pro každou reprezentaci. Test přeskočen.")
                continue

            try:
                chi_squared_stat, p_value = friedmanchisquare(*data_for_friedman_instance)

                print(f"  Chi-squared statistika: {chi_squared_stat:.4f}")
                print(f"  P-hodnota: {p_value:.4f}")
                print(f"  Stupně volnosti (df): {len(reps_included_in_test) - 1}")

                if p_value < alpha:
                    print(f"  Výsledek je statisticky významný (p < {alpha}).")
                    print(f"  => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci '{instance_name}'.")
                    
                    print("\n  --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---")
                    
                    k = len(reps_included_in_test)
                    N = min_runs
                    
                    if k < 2 or N < 1:
                        print("  INFO: Nedostatek dat pro provedení Nemenyiho testu.")
                    else:
                        q_alpha = q_critical_values_nemenyi.get(k)
                        if q_alpha is None:
                            print(f"  VAROVÁNÍ: Kritická hodnota pro k={k} není k dispozici. Nemenyiho test nelze provést.")
                        else:
                            CD = q_alpha * np.sqrt(k * (k + 1) / (6 * N))
                            print(f"  Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha={alpha}, k={k}, N={N}): {CD:.4f}")

                            transposed_runs_data = list(zip(*data_for_friedman_instance))

                            ranks_per_run = [rankdata(row) for row in transposed_runs_data]

                            mean_ranks = np.mean(ranks_per_run, axis=0)
                            
                            print("\n  Průměrné ranky reprezentací:")
                            for i, rep_name in enumerate(reps_included_in_test):
                                print(f"    {rep_name}: {mean_ranks[i]:.4f}")

                            print("\n  Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):")
                            for i in range(len(reps_included_in_test)):
                                for j in range(i + 1, len(reps_included_in_test)):
                                    rep1_name = reps_included_in_test[i]
                                    rep2_name = reps_included_in_test[j]
                                    
                                    diff = abs(mean_ranks[i] - mean_ranks[j])
                                    
                                    significance_msg = ""
                                    if diff > CD:
                                        significance_msg = f"Statisticky významný rozdíl (> CD)"
                                    else:
                                        significance_msg = f"Není významný rozdíl (<= CD)"
                                    
                                    print(f"    {rep1_name} vs {rep2_name}: Rozdíl={diff:.4f} ({significance_msg})")

                else:
                    print(f"  Výsledek není statisticky významný (p >= {alpha}).")
                    print(f"  => Neexistuje statisticky významný rozdíl mezi reprezentacemi pro instanci '{instance_name}'.")
                    print("  Post-hoc test není potřeba, protože celkový test neprokázal významný rozdíl.")

            except ValueError as e:
                print(f"  WARN: Chyba při provádění Friedmanova testu pro instanci '{instance_name}': {e}")
                print("  Zkontrolujte, zda mají všechny skupiny (reprezentace) dostatek dat a jsou platné.")
            except Exception as e:
                print(f"  Neočekávaná chyba při Friedmanově testu pro instanci '{instance_name}': {e}")
# Out:
# Spojuji výsledky z jednotlivých běhů...
# Načteno 744 výsledků z gnbg_results_fixed-point.pkl
# Načteno 744 výsledků z gnbg_results_gray.pkl
# Načteno 744 výsledků z gnbg_results_ieee754.pkl
# Načteno 744 výsledků z gnbg_results_real-value.pkl
#
# Celkem spojeno 2976 výsledků z 4 souborů.
#
# Data připravena pro Friedmanův test.
# Nalezené unikátní instance (problémové funkce): ['f1', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f2', 'f20', 'f21', 'f22', 'f23', 'f24', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9']
# Nalezené unikátní reprezentace (metody): ['fixed-point', 'gray', 'ieee754', 'real-value']
#
# --- Friedman Rank Test (porovnání reprezentací pro každou instanci) ---
#
# ----- Instance: f1 -----
#   Chi-squared statistika: 83.3226
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f1'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.2903
#     gray: 2.0323
#     ieee754: 3.6774
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.2581 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.3871 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.2903 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.6452 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.6774 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f10 -----
#   Chi-squared statistika: 68.6903
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f10'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.7097
#     gray: 2.6129
#     ieee754: 3.6774
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.0968 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.9677 (Statisticky významný rozdíl (> CD))
#     fixed-point vs real-value: Rozdíl=1.7097 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.0645 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.6129 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.6774 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f11 -----
#   Chi-squared statistika: 35.2452
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f11'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.2903
#     gray: 1.8065
#     ieee754: 2.2581
#     real-value: 3.6452
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.4839 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.3548 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.4516 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.8387 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=1.3871 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f12 -----
#   Chi-squared statistika: 6.2903
#   P-hodnota: 0.0983
#   Stupně volnosti (df): 3
#   Výsledek není statisticky významný (p >= 0.05).
#   => Neexistuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f12'.
#   Post-hoc test není potřeba, protože celkový test neprokázal významný rozdíl.
#
# ----- Instance: f13 -----
#   Chi-squared statistika: 68.6129
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f13'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.3226
#     gray: 2.3226
#     ieee754: 3.3548
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.0000 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.3226 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.3226 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.3548 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f14 -----
#   Chi-squared statistika: 7.3742
#   P-hodnota: 0.0609
#   Stupně volnosti (df): 3
#   Výsledek není statisticky významný (p >= 0.05).
#   => Neexistuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f14'.
#   Post-hoc test není potřeba, protože celkový test neprokázal významný rozdíl.
#
# ----- Instance: f15 -----
#   Chi-squared statistika: 55.9161
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f15'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.9677
#     gray: 2.7419
#     ieee754: 3.2581
#     real-value: 1.0323
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.2258 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.2903 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.9355 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.5161 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.7097 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.2258 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f16 -----
#   Chi-squared statistika: 74.4968
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f16'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.4516
#     gray: 1.5161
#     ieee754: 3.5484
#     real-value: 1.4839
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.9355 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0968 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.9677 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=2.0323 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     ieee754 vs real-value: Rozdíl=2.0645 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f17 -----
#   Chi-squared statistika: 83.7097
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f17'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.4839
#     gray: 2.0000
#     ieee754: 3.5161
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.4839 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.5161 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0000 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.5161 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f18 -----
#   Chi-squared statistika: 10.4323
#   P-hodnota: 0.0152
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f18'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.0645
#     gray: 2.8387
#     ieee754: 2.1935
#     real-value: 2.9032
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.7742 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.1290 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=0.8387 (Není významný rozdíl (<= CD))
#     gray vs ieee754: Rozdíl=0.6452 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=0.0645 (Není významný rozdíl (<= CD))
#     ieee754 vs real-value: Rozdíl=0.7097 (Není významný rozdíl (<= CD))
#
# ----- Instance: f19 -----
#   Chi-squared statistika: 5.7871
#   P-hodnota: 0.1224
#   Stupně volnosti (df): 3
#   Výsledek není statisticky významný (p >= 0.05).
#   => Neexistuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f19'.
#   Post-hoc test není potřeba, protože celkový test neprokázal významný rozdíl.
#
# ----- Instance: f2 -----
#   Chi-squared statistika: 84.8710
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f2'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.3226
#     gray: 2.0000
#     ieee754: 3.6774
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.3226 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.3548 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.3226 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.6774 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0000 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.6774 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f20 -----
#   Chi-squared statistika: 40.9742
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f20'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.2258
#     gray: 1.7742
#     ieee754: 2.2581
#     real-value: 3.7419
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.4516 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.5161 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.4839 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.9677 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f21 -----
#   Chi-squared statistika: 43.2968
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f21'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.0323
#     gray: 3.2581
#     ieee754: 2.4194
#     real-value: 1.2903
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.2258 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.6129 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.7419 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.8387 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.9677 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=1.1290 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f22 -----
#   Chi-squared statistika: 29.1677
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f22'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.0968
#     gray: 2.0968
#     ieee754: 2.2258
#     real-value: 3.5806
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.0000 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.1290 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.1290 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=1.3548 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f23 -----
#   Chi-squared statistika: 7.7613
#   P-hodnota: 0.0512
#   Stupně volnosti (df): 3
#   Výsledek není statisticky významný (p >= 0.05).
#   => Neexistuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f23'.
#   Post-hoc test není potřeba, protože celkový test neprokázal významný rozdíl.
#
# ----- Instance: f24 -----
#   Chi-squared statistika: 15.8516
#   P-hodnota: 0.0012
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f24'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.1290
#     gray: 2.3226
#     ieee754: 2.2581
#     real-value: 3.2903
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.1935 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.1290 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.1613 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.0645 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=0.9677 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f3 -----
#   Chi-squared statistika: 85.8774
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f3'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.2581
#     gray: 2.0000
#     ieee754: 3.7419
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.2581 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.4839 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.2581 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.7419 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0000 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.7419 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f4 -----
#   Chi-squared statistika: 83.7097
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f4'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.5161
#     gray: 2.0000
#     ieee754: 3.4839
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.5161 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0323 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.5161 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0000 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.4839 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f5 -----
#   Chi-squared statistika: 81.9677
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f5'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.4516
#     gray: 2.0323
#     ieee754: 3.5161
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.4194 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0645 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.4516 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.5161 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f6 -----
#   Chi-squared statistika: 81.9677
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f6'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.4516
#     gray: 2.0323
#     ieee754: 3.5161
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=1.4194 (Statisticky významný rozdíl (> CD))
#     fixed-point vs ieee754: Rozdíl=0.0645 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.4516 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.4839 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.5161 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f7 -----
#   Chi-squared statistika: 62.1097
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f7'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 2.6452
#     gray: 2.9032
#     ieee754: 3.4516
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.2581 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.8065 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=1.6452 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=0.5484 (Není významný rozdíl (<= CD))
#     gray vs real-value: Rozdíl=1.9032 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.4516 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f8 -----
#   Chi-squared statistika: 71.2839
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f8'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.0000
#     gray: 2.3548
#     ieee754: 3.6452
#     real-value: 1.0000
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.6452 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.6452 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.0000 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.2903 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.3548 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.6452 (Statisticky významný rozdíl (> CD))
#
# ----- Instance: f9 -----
#   Chi-squared statistika: 63.3871
#   P-hodnota: 0.0000
#   Stupně volnosti (df): 3
#   Výsledek je statisticky významný (p < 0.05).
#   => Existuje statisticky významný rozdíl mezi reprezentacemi pro instanci 'f9'.
#
#   --- Post-hoc Nemenyiho test (porovnání párů reprezentací) ---
#   Kritická hodnota rozdílu (CD) pro Nemenyiho test (alpha=0.05, k=4, N=31): 0.8424
#
#   Průměrné ranky reprezentací:
#     fixed-point: 3.0323
#     gray: 2.4516
#     ieee754: 3.4839
#     real-value: 1.0323
#
#   Výsledky párového porovnání (rozdíl průměrných ranků vs. CD):
#     fixed-point vs gray: Rozdíl=0.5806 (Není významný rozdíl (<= CD))
#     fixed-point vs ieee754: Rozdíl=0.4516 (Není významný rozdíl (<= CD))
#     fixed-point vs real-value: Rozdíl=2.0000 (Statisticky významný rozdíl (> CD))
#     gray vs ieee754: Rozdíl=1.0323 (Statisticky významný rozdíl (> CD))
#     gray vs real-value: Rozdíl=1.4194 (Statisticky významný rozdíl (> CD))
#     ieee754 vs real-value: Rozdíl=2.4516 (Statisticky významný rozdíl (> CD))

# %% [markdown]
# It attempts to load .pkl files (e.g., gnbg_results_fixed-point.pkl) for a predefined set of genetic algorithm representations (fixed-point, gray, ieee754, real-value).
# It includes robust error handling for FileNotFoundError and other general exceptions during the loading process, printing informative warnings or errors.
# All successfully loaded results from different representations are combined into a single dataset.
# Data Filtering and Preparation:
#
# It filters the combined results to ensure that only entries containing essential information (instance, representation, and final_error) are included for analysis.
# These filtered results are then converted into a pandas.DataFrame.
# The final_error column is explicitly converted to a numeric type, and any rows with non-numeric or missing final_error values are removed.
# It performs checks to ensure that valid data remains after filtering and cleaning.
# Statistical Summary of Final Error:
#
# It groups the data by instance (benchmark problem) and representation.
# For each group, it calculates and displays key descriptive statistics for final_error: minimum, maximum, mean (average), standard deviation, and count of runs.
# These statistical values are formatted into scientific notation for clarity.
# Graphical Visualization (Box Plots):
#
# It sets up seaborn for plotting with a whitegrid style.
# It creates a plots directory if it doesn't already exist to store the generated graphs.
# For each unique benchmark instance, it generates a box plot:
# The x-axis represents the different genetic algorithm representations.
# The y-axis represents the final_error, which is displayed on a logarithmic scale (log) to accommodate wide ranges of error values.
# Each box plot visualizes the distribution (median, quartiles, and outliers) of the final_error for each representation.
# Mean final_error values are overlaid as red triangular scatter points on the box plots for easy comparison.
# Each plot is given a descriptive title and axis labels.
# Plots are saved as PNG image files (e.g., final_error_InstanceName.png) within the plots directory.

# %%
print("Spojuji výsledky z jednotlivých běhů...")

representations_to_run = ['fixed-point', 'gray', 'ieee754', 'real-value']

all_combined_results = []
loaded_files_count = 0

for rep in representations_to_run:
    filename = f"gnbg_results_{rep}.pkl"
    try:
        with open(filename, 'rb') as f:
            results_for_rep = pickle.load(f)
            all_combined_results.extend(results_for_rep)
            print(f"Načteno {len(results_for_rep)} výsledků z {filename}")
            loaded_files_count += 1
    except FileNotFoundError:
        print(f"VAROVÁNÍ: Soubor {filename} nebyl nalezen. Přeskakuji.")
    except Exception as e:
        print(f"CHYBA při načítání souboru {filename}: {e}")

if not all_combined_results:
    print("CHYBA: Nepodařilo se načíst žádné výsledky. Nelze pokračovat s analýzou final_error.")
else:
    print(f"\nCelkem spojeno {len(all_combined_results)} výsledků z {loaded_files_count} souborů.")

    filtered_results = [
        run for run in all_combined_results
        if 'instance' in run and 'representation' in run and 'final_error' in run
    ]

    if not filtered_results:
        print("CHYBA: V načtených datech nebyly nalezeny žádné záznamy s 'final_error'.")
    else:
        df_final_error = pd.DataFrame(filtered_results)

        df_final_error['final_error'] = pd.to_numeric(df_final_error['final_error'], errors='coerce')
        df_final_error.dropna(subset=['final_error'], inplace=True)

        if df_final_error.empty:
            print("CHYBA: Po filtrování a čištění dat pro 'final_error' nezůstala žádná platná data.")
        else:
            print(f"\nDataFrame pro 'final_error' vytvořen s {len(df_final_error)} záznamy.")
            print(f"Unikátní instance pro analýzu: {df_final_error['instance'].unique()}")
            print(f"Unikátní reprezentace pro analýzu: {df_final_error['representation'].unique()}")

            print("\n--- Statistiky Final Error (Min, Max, Průměr, Směrodatná odchylka) ---")

            stats_final_error = df_final_error.groupby(['instance', 'representation'])['final_error'].agg(
                min_error='min',
                max_error='max',
                mean_error='mean',
                std_error='std',
                count='count'
            ).reset_index()

            stats_final_error['mean_error'] = stats_final_error['mean_error'].apply(lambda x: f"{x:.4e}")
            stats_final_error['std_error'] = stats_final_error['std_error'].apply(lambda x: f"{x:.4e}")
            stats_final_error['min_error'] = stats_final_error['min_error'].apply(lambda x: f"{x:.4e}")
            stats_final_error['max_error'] = stats_final_error['max_error'].apply(lambda x: f"{x:.4e}")

            print(stats_final_error.to_string(index=False))


            print("\n--- Grafické zobrazení Final Error ---")

            sns.set_theme(style="whitegrid")

            if not os.path.exists('plots'):
                os.makedirs('plots')

            for instance_name in df_final_error['instance'].unique():
                fig, ax = plt.subplots(figsize=(10, 6))

                subset_df = df_final_error[df_final_error['instance'] == instance_name]

                sns.boxplot(x='representation', y='final_error', data=subset_df, ax=ax, hue='representation', palette='viridis', legend=False)

                ax.set_title(f'Final Error Distribution for {instance_name}')
                ax.set_xlabel('Representation')
                ax.set_ylabel('Final Error')
                ax.set_yscale('log')

                mean_values = subset_df.groupby('representation')['final_error'].mean().reset_index()
                sns.scatterplot(x='representation', y='final_error', data=mean_values, ax=ax,
                                marker='^', color='red', s=100, zorder=5, label='Mean')

                ax.legend(title='Metrics')

                plt.tight_layout()

                safe_instance_name = instance_name.replace(" ", "_").replace("/", "_").replace("\\", "_")
                plot_filename = f"plots/final_error_{safe_instance_name}.png"
                plt.savefig(plot_filename)
                print(f"Graf pro instanci '{instance_name}' uložen jako: {plot_filename}")

                plt.close(fig)

            print("\nVšechny grafy byly úspěšně uloženy do složky 'plots'.")
# Out:
# Spojuji výsledky z jednotlivých běhů...
# Načteno 744 výsledků z gnbg_results_fixed-point.pkl
# Načteno 744 výsledků z gnbg_results_gray.pkl
# Načteno 744 výsledků z gnbg_results_ieee754.pkl
# Načteno 744 výsledků z gnbg_results_real-value.pkl
#
# Celkem spojeno 2976 výsledků z 4 souborů.
#
# DataFrame pro 'final_error' vytvořen s 2976 záznamy.
# Unikátní instance pro analýzu: ['f1' 'f10' 'f11' 'f12' 'f13' 'f14' 'f15' 'f16' 'f17' 'f18' 'f19' 'f2'
#  'f20' 'f21' 'f22' 'f23' 'f24' 'f3' 'f4' 'f5' 'f6' 'f7' 'f8' 'f9']
# Unikátní reprezentace pro analýzu: ['fixed-point' 'gray' 'ieee754' 'real-value']
#
# --- Statistiky Final Error (Min, Max, Průměr, Směrodatná odchylka) ---
# instance representation  min_error  max_error mean_error  std_error  count
#       f1    fixed-point 6.2990e+02 4.4375e+03 2.0655e+03 9.2617e+02     31
#       f1           gray 6.0790e-01 9.9574e+02 1.2300e+02 2.0103e+02     31
#       f1        ieee754 2.3378e+02 8.8610e+03 3.6241e+03 2.0776e+03     31
#       f1     real-value 1.1812e-04 4.9758e-04 2.8860e-04 8.3847e-05     31
#      f10    fixed-point 6.8009e+02 4.0162e+03 1.6427e+03 7.8875e+02     31
#      f10           gray 1.3035e+02 6.7310e+03 1.6389e+03 1.3117e+03     31
#      f10        ieee754 1.5038e+03 6.0150e+03 3.1721e+03 1.2317e+03     31
#      f10     real-value 1.3107e-03 3.0934e-02 6.5058e-03 6.2670e-03     31
#      f11    fixed-point 6.1995e+03 2.7563e+04 1.5572e+04 5.5717e+03     31
#      f11           gray 4.0940e+03 2.2687e+04 1.4110e+04 4.7175e+03     31
#      f11        ieee754 8.1891e+03 2.9524e+04 1.5744e+04 5.5772e+03     31
#      f11     real-value 1.6279e+04 2.9815e+04 2.2847e+04 3.2982e+03     31
#      f12    fixed-point 5.3406e+03 2.2159e+04 1.2206e+04 4.9468e+03     31
#      f12           gray 4.7449e+03 3.3017e+04 1.2625e+04 6.1429e+03     31
#      f12        ieee754 4.5826e+03 2.9592e+04 1.3016e+04 6.4053e+03     31
#      f12     real-value 5.8075e+03 1.4846e+04 9.7542e+03 2.2410e+03     31
#      f13    fixed-point 1.1282e+03 1.9580e+04 4.2522e+03 3.2833e+03     31
#      f13           gray 1.0360e+03 3.9195e+03 2.2103e+03 7.6472e+02     31
#      f13        ieee754 1.1169e+03 7.9507e+03 3.8825e+03 1.5544e+03     31
#      f13     real-value 7.0445e+02 1.2750e+03 9.7957e+02 1.3658e+02     31
#      f14    fixed-point 8.7429e+03 2.1290e+04 1.3825e+04 2.9906e+03     31
#      f14           gray 8.9638e+03 2.3069e+04 1.3459e+04 3.1956e+03     31
#      f14        ieee754 8.3047e+03 2.5268e+04 1.4893e+04 3.8228e+03     31
#      f14     real-value 1.0118e+04 1.7727e+04 1.2963e+04 1.7207e+03     31
#      f15    fixed-point 5.9491e+00 6.8372e+00 6.4163e+00 2.2169e-01     31
#      f15           gray 5.8867e+00 6.6917e+00 6.3159e+00 2.5003e-01     31
#      f15        ieee754 6.0215e+00 6.9911e+00 6.5332e+00 2.8071e-01     31
#      f15     real-value 5.4941e+00 6.0588e+00 5.8440e+00 1.0776e-01     31
#      f16    fixed-point 1.2864e+03 6.9995e+03 3.3363e+03 1.5244e+03     31
#      f16           gray 5.9701e-03 7.0296e+02 6.1020e+02 1.2688e+02     31
#      f16        ieee754 9.2790e+02 1.2022e+04 4.4248e+03 2.4941e+03     31
#      f16     real-value 5.2960e+02 6.8210e+02 6.5510e+02 4.8859e+01     31
#      f17    fixed-point 7.2011e+04 3.3692e+05 1.5601e+05 7.3755e+04     31
#      f17           gray 1.0659e+03 3.0319e+04 7.7803e+03 7.0416e+03     31
#      f17        ieee754 4.9895e+04 4.0761e+05 1.6765e+05 7.9758e+04     31
#      f17     real-value 1.1071e-02 6.8221e+02 5.3586e+02 2.6976e+02     31
#      f18    fixed-point 7.0926e+03 2.9067e+04 1.6039e+04 5.3792e+03     31
#      f18           gray 1.0222e+04 4.1437e+04 2.0084e+04 7.1201e+03     31
#      f18        ieee754 7.6738e+03 2.6644e+04 1.6746e+04 4.4936e+03     31
#      f18     real-value 1.3615e+04 2.9106e+04 1.9637e+04 3.9429e+03     31
#      f19    fixed-point 8.7639e+03 3.4551e+04 1.8485e+04 5.5272e+03     31
#      f19           gray 7.9339e+03 3.0297e+04 1.6192e+04 5.7387e+03     31
#      f19        ieee754 5.0461e+03 3.2799e+04 1.6310e+04 6.5081e+03     31
#      f19     real-value 1.0787e+04 2.4483e+04 1.6610e+04 3.6677e+03     31
#       f2    fixed-point 1.3794e+00 1.5258e+00 1.4749e+00 3.2449e-02     31
#       f2           gray 1.0506e+00 1.3943e+00 1.1908e+00 9.7153e-02     31
#       f2        ieee754 1.3195e+00 1.5770e+00 1.4872e+00 5.3939e-02     31
#       f2     real-value 6.4015e-01 6.7655e-01 6.6208e-01 1.0278e-02     31
#      f20    fixed-point 9.0886e+00 1.2605e+01 1.0804e+01 8.9299e-01     31
#      f20           gray 9.1731e+00 1.2516e+01 1.0515e+01 8.8911e-01     31
#      f20        ieee754 9.3494e+00 1.2533e+01 1.0834e+01 8.4210e-01     31
#      f20     real-value 1.1268e+01 1.4066e+01 1.2213e+01 6.3820e-01     31
#      f21    fixed-point 1.6465e+01 1.2698e+02 5.9289e+01 3.0107e+01     31
#      f21           gray 3.4026e+01 1.1366e+02 7.2936e+01 2.0315e+01     31
#      f21        ieee754 5.0000e+00 1.1491e+02 4.8058e+01 3.8652e+01     31
#      f21     real-value 8.4310e+00 3.0894e+01 1.9542e+01 5.8432e+00     31
#      f22    fixed-point 2.6866e+04 9.0825e+04 5.6192e+04 1.7838e+04     31
#      f22           gray 2.1919e+04 1.2075e+05 6.0060e+04 2.0283e+04     31
#      f22        ieee754 2.4647e+04 1.5096e+05 6.1346e+04 2.5549e+04     31
#      f22     real-value 5.7692e+04 1.2875e+05 9.2227e+04 1.8427e+04     31
#      f23    fixed-point 2.5597e+01 5.2114e+01 3.7712e+01 6.2912e+00     31
#      f23           gray 2.8490e+01 4.6045e+01 3.6778e+01 4.5248e+00     31
#      f23        ieee754 2.7700e+01 5.4954e+01 3.8602e+01 6.2286e+00     31
#      f23     real-value 3.3865e+01 4.9276e+01 4.1526e+01 4.4719e+00     31
#      f24    fixed-point 1.2067e+02 1.8167e+02 1.5237e+02 1.5908e+01     31
#      f24           gray 1.2172e+02 1.7732e+02 1.5741e+02 1.6788e+01     31
#      f24        ieee754 1.3183e+02 1.8548e+02 1.5648e+02 1.3857e+01     31
#      f24     real-value 1.4738e+02 1.8435e+02 1.6777e+02 1.0791e+01     31
#       f3    fixed-point 1.9010e+08 1.8715e+09 8.0993e+08 3.4881e+08     31
#       f3           gray 2.1741e+05 2.0448e+08 3.0020e+07 4.4415e+07     31
#       f3        ieee754 3.7758e+08 4.5011e+09 1.7353e+09 1.1535e+09     31
#       f3     real-value 1.8149e+01 1.1925e+02 5.6771e+01 2.0397e+01     31
#       f4    fixed-point 3.0055e+03 2.9991e+04 1.2854e+04 6.5875e+03     31
#       f4           gray 2.4700e+02 4.2077e+03 1.1548e+03 8.8527e+02     31
#       f4        ieee754 4.3082e+03 3.3104e+04 1.5092e+04 7.8301e+03     31
#       f4     real-value 2.6162e-03 1.0394e-02 5.2236e-03 1.9036e-03     31
#       f5    fixed-point 2.6695e+00 2.9452e+00 2.8266e+00 7.8276e-02     31
#       f5           gray 2.2884e+00 2.7769e+00 2.5146e+00 1.3126e-01     31
#       f5        ieee754 2.7103e+00 2.9847e+00 2.8509e+00 6.9071e-02     31
#       f5     real-value 1.3362e+00 1.4383e+00 1.3880e+00 2.3470e-02     31
#       f6    fixed-point 2.6883e+00 2.9270e+00 2.8275e+00 5.9886e-02     31
#       f6           gray 2.4492e+00 2.7206e+00 2.5779e+00 7.5358e-02     31
#       f6        ieee754 2.6607e+00 2.9492e+00 2.8487e+00 7.1768e-02     31
#       f6     real-value 1.5137e+00 1.8744e+00 1.7221e+00 9.6931e-02     31
#       f7    fixed-point 5.7878e+02 3.6083e+03 1.7651e+03 9.4732e+02     31
#       f7           gray 3.3120e+02 7.7296e+03 2.4157e+03 1.9178e+03     31
#       f7        ieee754 9.7195e+02 7.9323e+03 3.6868e+03 2.0685e+03     31
#       f7     real-value 8.9565e-04 3.2668e-03 1.5843e-03 4.9672e-04     31
#       f8    fixed-point 4.5258e+02 4.0858e+03 2.0095e+03 8.7803e+02     31
#       f8           gray 4.1810e+01 4.2852e+03 1.2524e+03 1.0479e+03     31
#       f8        ieee754 1.0980e+03 6.7596e+03 3.2205e+03 1.5423e+03     31
#       f8     real-value 8.1380e-04 4.1326e-03 2.0849e-03 8.3289e-04     31
#       f9    fixed-point 3.1161e+02 1.5511e+03 7.4345e+02 2.5630e+02     31
#       f9           gray 2.0792e+02 1.0999e+03 4.9252e+02 2.0307e+02     31
#       f9        ieee754 3.0341e+02 3.5674e+03 1.1007e+03 7.8857e+02     31
#       f9     real-value 1.6769e+01 4.6884e+02 1.0724e+02 8.6802e+01     31
#
# --- Grafické zobrazení Final Error ---
# Graf pro instanci 'f1' uložen jako: plots/final_error_f1.png
# Graf pro instanci 'f10' uložen jako: plots/final_error_f10.png
# Graf pro instanci 'f11' uložen jako: plots/final_error_f11.png
# Graf pro instanci 'f12' uložen jako: plots/final_error_f12.png
# Graf pro instanci 'f13' uložen jako: plots/final_error_f13.png
# Graf pro instanci 'f14' uložen jako: plots/final_error_f14.png
# Graf pro instanci 'f15' uložen jako: plots/final_error_f15.png
# Graf pro instanci 'f16' uložen jako: plots/final_error_f16.png
# Graf pro instanci 'f17' uložen jako: plots/final_error_f17.png
# Graf pro instanci 'f18' uložen jako: plots/final_error_f18.png
# Graf pro instanci 'f19' uložen jako: plots/final_error_f19.png
# Graf pro instanci 'f2' uložen jako: plots/final_error_f2.png
# Graf pro instanci 'f20' uložen jako: plots/final_error_f20.png
# Graf pro instanci 'f21' uložen jako: plots/final_error_f21.png
# Graf pro instanci 'f22' uložen jako: plots/final_error_f22.png
# Graf pro instanci 'f23' uložen jako: plots/final_error_f23.png
# Graf pro instanci 'f24' uložen jako: plots/final_error_f24.png
# Graf pro instanci 'f3' uložen jako: plots/final_error_f3.png
# Graf pro instanci 'f4' uložen jako: plots/final_error_f4.png
# Graf pro instanci 'f5' uložen jako: plots/final_error_f5.png
# Graf pro instanci 'f6' uložen jako: plots/final_error_f6.png
# Graf pro instanci 'f7' uložen jako: plots/final_error_f7.png
# Graf pro instanci 'f8' uložen jako: plots/final_error_f8.png
# Graf pro instanci 'f9' uložen jako: plots/final_error_f9.png
#
# Všechny grafy byly úspěšně uloženy do složky 'plots'.
